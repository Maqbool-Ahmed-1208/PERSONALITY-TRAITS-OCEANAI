# %% [markdown]
# # AUDIO EXTRACTION

# %%
# import os
# import subprocess

# def list_videos(base_dir, extensions=('.mp4',)):
#     """
#     List all video files in the dataset directory.
#     :param base_dir: Path to the dataset base directory
#     :param extensions: Tuple of file extensions to include
#     :return: List of file paths for all videos
#     """
#     video_files = []
#     for root, dirs, files in os.walk(base_dir):
#         for file in files:
#             if file.endswith(extensions):
#                 video_files.append(os.path.join(root, file))
#     return video_files

# def extract_audio(video_files, output_base_dir):
#     """
#     Extract audio from video files and save as .wav files.
#     :param video_files: List of video file paths
#     :param output_base_dir: Base directory for saving audio files
#     """
#     for video_file in video_files:
#         # Generate output directory and file paths
#         relative_path = os.path.relpath(video_file, input_dir)
#         output_dir = os.path.join(output_base_dir, os.path.dirname(relative_path))
#         os.makedirs(output_dir, exist_ok=True)
#         output_file = os.path.join(output_dir, os.path.basename(video_file).replace('.mp4', '.wav'))
        
#         # Run FFmpeg to extract audio
#         subprocess.run(['ffmpeg', '-i', video_file, '-vn', '-acodec', 'pcm_s16le', '-ar', '44100', '-ac', '2', output_file])
#         print(f"Extracted: {video_file} -> {output_file}")

# %%
# # Base directories
# input_dir = '/kaggle/input/first-impression-v2-train-dataset/train-1'
# output_base_dir = '/kaggle/working/fi_audio_train_dataset/train-1'

# # List video files
# video_files = list_videos(input_dir)

# print(f"Found {len(video_files)} video files.")
# extract_audio(video_files, output_base_dir)

# %%
# print("done")

# %% [markdown]
# ---

# %% [markdown]
# # FEATURE EXTRACTION

# %%
# import os
# import shutil

# # Specify the folder to delete
# folder_path = "/kaggle/working/segmented_audio"

# # Check if the folder exists
# if os.path.exists(folder_path):
#     # Delete the folder and its contents
#     shutil.rmtree(folder_path)
#     print(f"Folder '{folder_path}' has been deleted.")
# else:
#     print(f"Folder '{folder_path}' does not exist.")

# %%
# import os

# # Specify the file to delete
# file_path = "/kaggle/working/audio_feature_extraction/train_6_af.csv"

# # Check if the file exists
# if os.path.exists(file_path):
#     # Delete the file
#     os.remove(file_path)
#     print(f"File '{file_path}' has been deleted.")
# else:
#     print(f"File '{file_path}' does not exist.")
# Out:
# File '/kaggle/working/audio_feature_extraction/train_6_af.csv' does not exist.

# %% [markdown]
# ## DEEP AND HC FEATURE EXTRACTION

# %%
import os

def list_audio_files(base_dir, extension=".wav"):
    """
    List all audio files in the dataset directory.

    :param base_dir: Path to the dataset base directory
    :param extension: File extension to look for (default is ".wav")
    :return: List of file paths for all audio files
    """
    audio_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(extension):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Example usage
base_dir = "/kaggle/working/fi_audio_train_dataset/train-1"  # Replace with the path to your dataset
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 960 audio files.

# %%
import os
import pandas as pd

output_dir = "audio_feature_extraction"

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Define output file and columns
output_file = "audio_feature_extraction/train_1_af.csv"
columns = ['Audio_ID', 'Segment_ID'] + [f'Deep_{i}' for i in range(512)] + [f'Hc_{i}' for i in range(25)]

# Initialize the CSV if it doesn't exist
if not os.path.exists(output_file):
    pd.DataFrame(columns=columns).to_csv(output_file, index=False)

# %%
from pydub import AudioSegment

def segment_audio(audio_path, segment_duration=2, skip_duration=3):
    audio = AudioSegment.from_file(audio_path)
    segments = []
    audio_duration = len(audio) / 1000  # in seconds
    for start in range(0, int(audio_duration - segment_duration), skip_duration):  # Segment based on audio length
        segment = audio[start * 1000:(start + segment_duration) * 1000]  # Segment duration in milliseconds
        if len(segment) < segment_duration * 1000:
            segment = segment + AudioSegment.silent(duration=(segment_duration * 1000 - len(segment)))  # Pad with silence
        segments.append(segment)
    return segments

# %%
import numpy as np
import librosa
from PIL import Image
import torch
import torchvision.transforms as transforms

# Load pretrained emotional VGG-16 model
vgg_model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', pretrained=True)
vgg_model.eval()

def extract_deep_features(segments):
    features = []
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    for segment in segments:
        # Compute log-Mel spectrogram
        samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
        mel_spec = librosa.feature.melspectrogram(y=samples, sr=16000, n_mels=128, fmax=8000, hop_length=512, win_length=2048)
        log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram to range 0-255 for image conversion
        log_mel_spec = np.clip(log_mel_spec, a_min=-80, a_max=0)  # Log scale
        log_mel_spec = (log_mel_spec + 80) * (255.0 / 80.0)  # Normalize to [0, 255]

        # Convert to image and resize
        image = Image.fromarray(log_mel_spec.astype(np.uint8)).convert("RGB")
        image = transform(image).unsqueeze(0)

        # Extract features using VGG-16
        with torch.no_grad():
            deep_feature = vgg_model(image).numpy()
        features.append(deep_feature)

    return features
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# pip install opensmile

# %%
import opensmile
from opensmile import Smile, FeatureSet, FeatureLevel

smile = Smile(
    feature_set=FeatureSet.eGeMAPSv02,
    feature_level=FeatureLevel.Functionals
)

def extract_egemaps(segment):
    """
    Extract eGeMAPS features using openSMILE.

    :param segment: Audio segment
    :return: Hand-crafted features as a numpy array
    """
    samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
    features = smile.process_signal(samples, sampling_rate=16000).to_numpy()
    return features

# %%
def save_features(audio_id, segment_id, deep_feat, hc_feat):
    """
    Save the extracted features to the CSV file.

    :param audio_id: ID of the audio file
    :param segment_id: ID of the audio segment
    :param deep_feat: Deep features for the segment
    :param hc_feat: Hand-crafted features for the segment
    """
    # Aggregate features (e.g., mean)
    combined_features = {
        'Audio_ID': audio_id,
        'Segment_ID': segment_id,
    }
    combined_features.update({f'Deep_{i}': deep_feat.mean(axis=0)[i] for i in range(512)})
    combined_features.update({f'Hc_{i}': hc_feat.mean(axis=0)[i] for i in range(25)})

    # Append to CSV
    feature_row = pd.DataFrame([combined_features])
    feature_row.to_csv(output_file, mode='a', header=False, index=False)

# %%
def process_audio_files(audio_files):
    for audio_path in audio_files:
        audio_id = os.path.splitext(os.path.basename(audio_path))[0]
        print(f"Processing {audio_id}...")

        # Segment the audio
        segments = segment_audio(audio_path)

        for segment_id, segment in enumerate(segments):
            # Extract features
            deep_feat = extract_deep_features([segment])[0]
            hc_feat = extract_egemaps(segment)

            # Save features to CSV
            save_features(audio_id, segment_id, deep_feat, hc_feat)

    print(f"All features saved to {output_file}")

# %%
# Step 1: List all audio files in the dataset directory
# base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with your path
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")

# Step 2: Process all audio files
process_audio_files(audio_files)  # This function is already defined in the previous pipeline
# Out:
# Found 960 audio files.
# Processing 69BopbFc34U.004...
# Processing p_Z4QGqu4Qo.004...
# Processing 6TkMavTyimI.000...
# Processing kdPRPO3wgg0.004...
# Processing PTV5TBVRHxo.002...
# Processing dmycfNpiWCE.005...
# Processing fEZrAGQoh_g.001...
# Processing u50B6bIkN9g.002...
# Processing zvX4fNj0uxk.004...
# Processing si_gZCrLa4A.005...
# Processing D4TU65xbF4g.000...
# Processing 8i7H-uSCQcc.004...
# Processing ya8Ec_yTai8.002...
# Processing t899haDGi38.003...
# Processing ZiKxJbVI5_g.002...
# Processing Sb1b8JMVhLs.002...
# Processing bFwtVtZodIg.002...
# Processing KahSwziq8F0.002...
# Processing PtA7yAu9-VE.005...
# Processing C0UMWrEJ2x0.005...
# Processing JO44XCaQGVY.000...
# Processing GwKmjEb3qN0.001...
# Processing 78zauTEQ-k8.001...
# Processing orlXEgAepGo.002...
# Processing ld7mBR4v3yU.002...
# Processing fEix0DPOWtg.005...
# Processing Vk3scj5vhd4.004...
# Processing LeQKH1vAVpg.005...
# Processing 2fzLibPAtvI.005...
# Processing L-C1blPD_ec.000...
# Processing e2EmGXRJ1K0.001...
# Processing nDsTSmE73M0.000...
# Processing OD_gyCYpR8U.002...
# Processing osqQpQsJNPQ.000...
# Processing 8py6SksNsZQ.005...
# Processing w2FKw8IhbFw.001...
# Processing jOTlJwOBSd4.004...
# Processing t3A2UMN3JeE.000...
# Processing PYYC0Jiwfdg.000...
# Processing -R2SZu3SYgM.000...
# Processing 2IwWILRuuNU.003...
# Processing c3SQSM9OIsA.001...
# Processing in-HuMgiDCE.002...
# Processing jZDlFzVUZwY.005...
# Processing dNXqs5HNijI.004...
# Processing a84s1DYag-I.001...
# Processing YGrCXe2-fVk.004...
# Processing datcFOBWYxc.005...
# Processing rBxWZzkEncE.004...
# Processing 7UQt8QB3cQY.003...
# Processing 4VwcU0ROy5k.001...
# Processing Gdv79afXNKE.005...
# Processing 5kY-Iv6UkeU.003...
# Processing WpMPrPnk1po.000...
# Processing nKx64KH7Xks.005...
# Processing r1v6EmZv7-o.002...
# Processing vHIBCKwJLEY.001...
# Processing OoxYhDbzWwg.005...
# Processing 98fnGDVky00.003...
# Processing ZiKxJbVI5_g.004...
# Processing YPnuq0tDDqk.000...
# Processing kUpkeJDcxaE.000...
# Processing 9Crw2RtrBcY.004...
# Processing aMmEPRJGocM.004...
# Processing pT8nyxks1Q4.005...
# %%
print("done")
# Out:
# done

# %% [markdown]
# ## DEEP AND HC FEATURE EXTRACTION

# %%
import os

def list_audio_files(base_dir, extension=".wav"):
    """
    List all audio files in the dataset directory.

    :param base_dir: Path to the dataset base directory
    :param extension: File extension to look for (default is ".wav")
    :return: List of file paths for all audio files
    """
    audio_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(extension):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Example usage
base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with the path to your dataset
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 960 audio files.

# %%
import os
import pandas as pd

output_dir = "audio_feature_extraction"

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Define output file and columns
output_file = "audio_feature_extraction/train_2_af.csv"
columns = ['Audio_ID', 'Segment_ID'] + [f'Deep_{i}' for i in range(512)] + [f'Hc_{i}' for i in range(25)]

# Initialize the CSV if it doesn't exist
if not os.path.exists(output_file):
    pd.DataFrame(columns=columns).to_csv(output_file, index=False)

# %%
from pydub import AudioSegment

def segment_audio(audio_path, segment_duration=2, skip_duration=3):
    audio = AudioSegment.from_file(audio_path)
    segments = []
    audio_duration = len(audio) / 1000  # in seconds
    for start in range(0, int(audio_duration - segment_duration), skip_duration):  # Segment based on audio length
        segment = audio[start * 1000:(start + segment_duration) * 1000]  # Segment duration in milliseconds
        if len(segment) < segment_duration * 1000:
            segment = segment + AudioSegment.silent(duration=(segment_duration * 1000 - len(segment)))  # Pad with silence
        segments.append(segment)
    return segments

# %%
import numpy as np
import librosa
from PIL import Image
import torch
import torchvision.transforms as transforms

# Load pretrained emotional VGG-16 model
vgg_model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', pretrained=True)
vgg_model.eval()

def extract_deep_features(segments):
    features = []
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    for segment in segments:
        # Compute log-Mel spectrogram
        samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
        mel_spec = librosa.feature.melspectrogram(y=samples, sr=16000, n_mels=128, fmax=8000, hop_length=512, win_length=2048)
        log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram to range 0-255 for image conversion
        log_mel_spec = np.clip(log_mel_spec, a_min=-80, a_max=0)  # Log scale
        log_mel_spec = (log_mel_spec + 80) * (255.0 / 80.0)  # Normalize to [0, 255]

        # Convert to image and resize
        image = Image.fromarray(log_mel_spec.astype(np.uint8)).convert("RGB")
        image = transform(image).unsqueeze(0)

        # Extract features using VGG-16
        with torch.no_grad():
            deep_feature = vgg_model(image).numpy()
        features.append(deep_feature)

    return features
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# pip install opensmile

# %%
import opensmile
from opensmile import Smile, FeatureSet, FeatureLevel

smile = Smile(
    feature_set=FeatureSet.eGeMAPSv02,
    feature_level=FeatureLevel.Functionals
)

def extract_egemaps(segment):
    """
    Extract eGeMAPS features using openSMILE.

    :param segment: Audio segment
    :return: Hand-crafted features as a numpy array
    """
    samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
    features = smile.process_signal(samples, sampling_rate=16000).to_numpy()
    return features

# %%
def save_features(audio_id, segment_id, deep_feat, hc_feat):
    """
    Save the extracted features to the CSV file.

    :param audio_id: ID of the audio file
    :param segment_id: ID of the audio segment
    :param deep_feat: Deep features for the segment
    :param hc_feat: Hand-crafted features for the segment
    """
    # Aggregate features (e.g., mean)
    combined_features = {
        'Audio_ID': audio_id,
        'Segment_ID': segment_id,
    }
    combined_features.update({f'Deep_{i}': deep_feat.mean(axis=0)[i] for i in range(512)})
    combined_features.update({f'Hc_{i}': hc_feat.mean(axis=0)[i] for i in range(25)})

    # Append to CSV
    feature_row = pd.DataFrame([combined_features])
    feature_row.to_csv(output_file, mode='a', header=False, index=False)

# %%
def process_audio_files(audio_files):
    for audio_path in audio_files:
        audio_id = os.path.splitext(os.path.basename(audio_path))[0]
        print(f"Processing {audio_id}...")

        # Segment the audio
        segments = segment_audio(audio_path)

        for segment_id, segment in enumerate(segments):
            # Extract features
            deep_feat = extract_deep_features([segment])[0]
            hc_feat = extract_egemaps(segment)

            # Save features to CSV
            save_features(audio_id, segment_id, deep_feat, hc_feat)

    print(f"All features saved to {output_file}")

# %%
# Step 1: List all audio files in the dataset directory
# base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with your path
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")

# Step 2: Process all audio files
process_audio_files(audio_files)  # This function is already defined in the previous pipeline
# Out:
# Found 960 audio files.
# Processing djsoQkroHpo.001...
# Processing 3Vr5-zedeWk.004...
# Processing xGo_wImhwkQ.003...
# Processing rTG9gtci67c.004...
# Processing CQMH9Qguuao.003...
# Processing dB-kMg4t-V8.001...
# Processing BLeDNfK2quI.002...
# Processing 44rxmXiga90.002...
# Processing M0U48Lm33A8.003...
# Processing C-48U5oDuvw.003...
# Processing mBJTwQsDC4M.003...
# Processing bJktioZ5Yxk.004...
# Processing 7LHmNEH65Pk.002...
# Processing huIQlWsIEvY.004...
# Processing noepjVnUVFY.001...
# Processing dB65He57Ki8.005...
# Processing EeI8iXLDfc0.005...
# Processing 176vWywoq9E.004...
# Processing fBMKlYUjA9E.000...
# Processing G7QTNbKbu_4.005...
# Processing NDC375coN1o.005...
# Processing TaTMtWvSmu4.000...
# Processing fBcc1UMtZME.001...
# Processing TNtcyfM9jak.003...
# Processing 8aLr0vNobr4.001...
# Processing p7-JUvStF4w.000...
# Processing UzgW75Fd4jU.001...
# Processing c4XnKouozXU.003...
# Processing 3gKpBq-1yG4.000...
# Processing Kmrd1MsZKmQ.001...
# Processing jgyDXrhO3n4.000...
# Processing EeI8iXLDfc0.001...
# Processing US4PxgfKDeA.000...
# Processing Cl7vQ9QR0es.005...
# Processing lyZZSU1ziCQ.003...
# Processing WYXRdYT4F0Q.003...
# Processing rzKtAeWgZH0.003...
# Processing Pc-oQQwkIv8.001...
# Processing f7E26XfU8rw.003...
# Processing WRz1F6DqmRQ.005...
# Processing jgyDXrhO3n4.003...
# Processing 5VG1EgzvprE.000...
# Processing GR-P1m_Yvm0.000...
# Processing wuhoIm_jPc0.002...
# Processing HT_8WpgGqjk.004...
# Processing LtBYojIGYEc.001...
# Processing 38fE5B4ghw0.003...
# Processing lyznxF-Pj6g.001...
# Processing T4eZ81aJwJI.000...
# Processing oU7zAWm_01o.003...
# Processing 8aPfoJiDeBY.004...
# Processing og8vtyRh_bc.001...
# Processing 0gv5Z0qt2jc.000...
# Processing nLB29nx1Jp4.001...
# Processing V7_h3URfSFY.000...
# Processing YuoLr4xDvbE.002...
# Processing 3y3au0hVfm8.001...
# Processing E3z1D7CKoOA.003...
# Processing fY4tctYZTz8.003...
# Processing KhMsmtSC5Lg.000...
# Processing EL1Q7x_1a74.001...
# Processing 0gv5Z0qt2jc.005...
# Processing VmV8NIvVVkw.000...
# All features saved to audio_feature_extraction/train_2_af.csv

# %%
print("done")
# Out:
# done

# %% [markdown]
# ## DEEP AND HC FEATURE EXTRACTION

# %%
import os

def list_audio_files(base_dir, extension=".wav"):
    """
    List all audio files in the dataset directory.

    :param base_dir: Path to the dataset base directory
    :param extension: File extension to look for (default is ".wav")
    :return: List of file paths for all audio files
    """
    audio_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(extension):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Example usage
base_dir = "/kaggle/working/fi_audio_train_dataset/train-3"  # Replace with the path to your dataset
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 960 audio files.

# %%
import os
import pandas as pd

output_dir = "audio_feature_extraction"

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Define output file and columns
output_file = "audio_feature_extraction/train_3_af.csv"
columns = ['Audio_ID', 'Segment_ID'] + [f'Deep_{i}' for i in range(512)] + [f'Hc_{i}' for i in range(25)]

# Initialize the CSV if it doesn't exist
if not os.path.exists(output_file):
    pd.DataFrame(columns=columns).to_csv(output_file, index=False)

# %%
from pydub import AudioSegment

def segment_audio(audio_path, segment_duration=2, skip_duration=3):
    audio = AudioSegment.from_file(audio_path)
    segments = []
    audio_duration = len(audio) / 1000  # in seconds
    for start in range(0, int(audio_duration - segment_duration), skip_duration):  # Segment based on audio length
        segment = audio[start * 1000:(start + segment_duration) * 1000]  # Segment duration in milliseconds
        if len(segment) < segment_duration * 1000:
            segment = segment + AudioSegment.silent(duration=(segment_duration * 1000 - len(segment)))  # Pad with silence
        segments.append(segment)
    return segments

# %%
import numpy as np
import librosa
from PIL import Image
import torch
import torchvision.transforms as transforms

# Load pretrained emotional VGG-16 model
vgg_model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', pretrained=True)
vgg_model.eval()

def extract_deep_features(segments):
    features = []
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    for segment in segments:
        # Compute log-Mel spectrogram
        samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
        mel_spec = librosa.feature.melspectrogram(y=samples, sr=16000, n_mels=128, fmax=8000, hop_length=512, win_length=2048)
        log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram to range 0-255 for image conversion
        log_mel_spec = np.clip(log_mel_spec, a_min=-80, a_max=0)  # Log scale
        log_mel_spec = (log_mel_spec + 80) * (255.0 / 80.0)  # Normalize to [0, 255]

        # Convert to image and resize
        image = Image.fromarray(log_mel_spec.astype(np.uint8)).convert("RGB")
        image = transform(image).unsqueeze(0)

        # Extract features using VGG-16
        with torch.no_grad():
            deep_feature = vgg_model(image).numpy()
        features.append(deep_feature)

    return features
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# pip install opensmile

# %%
import opensmile
from opensmile import Smile, FeatureSet, FeatureLevel

smile = Smile(
    feature_set=FeatureSet.eGeMAPSv02,
    feature_level=FeatureLevel.Functionals
)

def extract_egemaps(segment):
    """
    Extract eGeMAPS features using openSMILE.

    :param segment: Audio segment
    :return: Hand-crafted features as a numpy array
    """
    samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
    features = smile.process_signal(samples, sampling_rate=16000).to_numpy()
    return features

# %%
def save_features(audio_id, segment_id, deep_feat, hc_feat):
    """
    Save the extracted features to the CSV file.

    :param audio_id: ID of the audio file
    :param segment_id: ID of the audio segment
    :param deep_feat: Deep features for the segment
    :param hc_feat: Hand-crafted features for the segment
    """
    # Aggregate features (e.g., mean)
    combined_features = {
        'Audio_ID': audio_id,
        'Segment_ID': segment_id,
    }
    combined_features.update({f'Deep_{i}': deep_feat.mean(axis=0)[i] for i in range(512)})
    combined_features.update({f'Hc_{i}': hc_feat.mean(axis=0)[i] for i in range(25)})

    # Append to CSV
    feature_row = pd.DataFrame([combined_features])
    feature_row.to_csv(output_file, mode='a', header=False, index=False)

# %%
def process_audio_files(audio_files):
    for audio_path in audio_files:
        audio_id = os.path.splitext(os.path.basename(audio_path))[0]
        print(f"Processing {audio_id}...")

        # Segment the audio
        segments = segment_audio(audio_path)

        for segment_id, segment in enumerate(segments):
            # Extract features
            deep_feat = extract_deep_features([segment])[0]
            hc_feat = extract_egemaps(segment)

            # Save features to CSV
            save_features(audio_id, segment_id, deep_feat, hc_feat)

    print(f"All features saved to {output_file}")

# %%
# Step 1: List all audio files in the dataset directory
# base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with your path
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")

# Step 2: Process all audio files
process_audio_files(audio_files)  # This function is already defined in the previous pipeline
# Out:
# Found 960 audio files.
# Processing BS0wgLXqFgc.003...
# Processing bcRPLKygrNk.000...
# Processing FoWuHvikyqU.001...
# Processing F4UeAogUMMs.004...
# Processing lLObIVKYDUI.004...
# Processing ai-RZb0ZpKI.002...
# Processing IMCEXoAkZv4.005...
# Processing JFKZEGDhcRs.000...
# Processing 6wIEiqmuHOM.000...
# Processing PooFvZH6fK0.001...
# Processing 5Eez38v8TuU.005...
# Processing SyaRn3MHEIE.003...
# Processing TNjEJGdqmH0.005...
# Processing 3taD1fEPfC8.004...
# Processing OhHg1lyxe4I.000...
# Processing Gk94xrcmFts.000...
# Processing s6gN_358tk4.001...
# Processing Y1LrgyCJtpU.005...
# Processing 0ZK5jQAvhFo.004...
# Processing cvg03XGFjCk.001...
# Processing oVSMxtPpQ0M.003...
# Processing XLV7teADu3c.002...
# Processing UWVOT3YPQH4.002...
# Processing SFRis1tTZWk.003...
# Processing PgpMUHH8lEI.005...
# Processing k1eXxMAfnIY.005...
# Processing r9TaaVTo8Y8.000...
# Processing z3DO3tdrsnQ.001...
# Processing kzDQXSGGomg.002...
# Processing V7_h3URfSFY.003...
# Processing DXw4lVoiiWY.002...
# Processing LWylAwr9kJI.002...
# Processing HTF8k56_Oxo.005...
# Processing hG-pwa191bw.002...
# Processing squHxV3QXlQ.002...
# Processing tvKUJujTUEo.005...
# Processing vLAHfIjmRMc.005...
# Processing cx8IycWgMVs.005...
# Processing CqQavmWSLrI.003...
# Processing feg-RNvT-t0.000...
# Processing m04e9ylCoK0.000...
# Processing 3LAaFUSGvsU.003...
# Processing KNOHhnRMpSw.002...
# Processing Jr6GmDtvTK0.000...
# Processing uTluOTPA7e4.002...
# Processing YocrYFLm4CM.000...
# Processing YPMffqhP0C8.004...
# Processing r1v6EmZv7-o.005...
# Processing lkdQjIunxSE.003...
# Processing LqtBNNM2jIw.004...
# Processing Vd9biSOZ5CI.003...
# Processing aoRjg63uRww.004...
# Processing QS7TwjzkYiU.004...
# Processing dRr2JtdzUpU.005...
# Processing GUxm9AWVpOI.003...
# Processing L5kpy0SA7os.003...
# Processing N5nIQZMW_ig.003...
# Processing LGdzP-r_G3U.005...
# Processing xZFZ0Mvjiuo.005...
# Processing 98fnGDVky00.001...
# Processing owRKOW0ymCM.003...
# Processing VjYqagJ4xt8.001...
# Processing B4ducm9sydg.002...
# All features saved to audio_feature_extraction/train_3_af.csv

# %%
print("done")
# Out:
# done

# %% [markdown]
# ## DEEP AND HC FEATURE EXTRACTION

# %%
import os

def list_audio_files(base_dir, extension=".wav"):
    """
    List all audio files in the dataset directory.

    :param base_dir: Path to the dataset base directory
    :param extension: File extension to look for (default is ".wav")
    :return: List of file paths for all audio files
    """
    audio_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(extension):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Example usage
base_dir = "/kaggle/working/fi_audio_train_dataset/train-4"  # Replace with the path to your dataset
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 960 audio files.

# %%
import os
import pandas as pd

output_dir = "audio_feature_extraction"

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Define output file and columns
output_file = "audio_feature_extraction/train_4_af.csv"
columns = ['Audio_ID', 'Segment_ID'] + [f'Deep_{i}' for i in range(512)] + [f'Hc_{i}' for i in range(25)]

# Initialize the CSV if it doesn't exist
if not os.path.exists(output_file):
    pd.DataFrame(columns=columns).to_csv(output_file, index=False)

# %%
from pydub import AudioSegment

def segment_audio(audio_path, segment_duration=2, skip_duration=3):
    audio = AudioSegment.from_file(audio_path)
    segments = []
    audio_duration = len(audio) / 1000  # in seconds
    for start in range(0, int(audio_duration - segment_duration), skip_duration):  # Segment based on audio length
        segment = audio[start * 1000:(start + segment_duration) * 1000]  # Segment duration in milliseconds
        if len(segment) < segment_duration * 1000:
            segment = segment + AudioSegment.silent(duration=(segment_duration * 1000 - len(segment)))  # Pad with silence
        segments.append(segment)
    return segments

# %%
import numpy as np
import librosa
from PIL import Image
import torch
import torchvision.transforms as transforms

# Load pretrained emotional VGG-16 model
vgg_model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', pretrained=True)
vgg_model.eval()

def extract_deep_features(segments):
    features = []
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    for segment in segments:
        # Compute log-Mel spectrogram
        samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
        mel_spec = librosa.feature.melspectrogram(y=samples, sr=16000, n_mels=128, fmax=8000, hop_length=512, win_length=2048)
        log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram to range 0-255 for image conversion
        log_mel_spec = np.clip(log_mel_spec, a_min=-80, a_max=0)  # Log scale
        log_mel_spec = (log_mel_spec + 80) * (255.0 / 80.0)  # Normalize to [0, 255]

        # Convert to image and resize
        image = Image.fromarray(log_mel_spec.astype(np.uint8)).convert("RGB")
        image = transform(image).unsqueeze(0)

        # Extract features using VGG-16
        with torch.no_grad():
            deep_feature = vgg_model(image).numpy()
        features.append(deep_feature)

    return features
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# pip install opensmile

# %%
import opensmile
from opensmile import Smile, FeatureSet, FeatureLevel

smile = Smile(
    feature_set=FeatureSet.eGeMAPSv02,
    feature_level=FeatureLevel.Functionals
)

def extract_egemaps(segment):
    """
    Extract eGeMAPS features using openSMILE.

    :param segment: Audio segment
    :return: Hand-crafted features as a numpy array
    """
    samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
    features = smile.process_signal(samples, sampling_rate=16000).to_numpy()
    return features

# %%
def save_features(audio_id, segment_id, deep_feat, hc_feat):
    """
    Save the extracted features to the CSV file.

    :param audio_id: ID of the audio file
    :param segment_id: ID of the audio segment
    :param deep_feat: Deep features for the segment
    :param hc_feat: Hand-crafted features for the segment
    """
    # Aggregate features (e.g., mean)
    combined_features = {
        'Audio_ID': audio_id,
        'Segment_ID': segment_id,
    }
    combined_features.update({f'Deep_{i}': deep_feat.mean(axis=0)[i] for i in range(512)})
    combined_features.update({f'Hc_{i}': hc_feat.mean(axis=0)[i] for i in range(25)})

    # Append to CSV
    feature_row = pd.DataFrame([combined_features])
    feature_row.to_csv(output_file, mode='a', header=False, index=False)

# %%
def process_audio_files(audio_files):
    for audio_path in audio_files:
        audio_id = os.path.splitext(os.path.basename(audio_path))[0]
        print(f"Processing {audio_id}...")

        # Segment the audio
        segments = segment_audio(audio_path)

        for segment_id, segment in enumerate(segments):
            # Extract features
            deep_feat = extract_deep_features([segment])[0]
            hc_feat = extract_egemaps(segment)

            # Save features to CSV
            save_features(audio_id, segment_id, deep_feat, hc_feat)

    print(f"All features saved to {output_file}")

# %%
# Step 1: List all audio files in the dataset directory
# base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with your path
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")

# Step 2: Process all audio files
process_audio_files(audio_files)  # This function is already defined in the previous pipeline
# Out:
# Found 960 audio files.
# Processing Zi7QHI_5ipU.004...
# Processing nex61B854Ms.003...
# Processing G-25EWOIGNs.000...
# Processing MrYEK0nvnAo.002...
# Processing shAhNNV-zHA.005...
# Processing k2buv6xZ4_o.003...
# Processing Rops7WYMCCY.001...
# Processing lkdQjIunxSE.000...
# Processing Oe7ItP7gS4w.004...
# Processing OTXGM3Guxy4.000...
# Processing 8mZZlnbmOYE.001...
# Processing atdhaGEh_0c.000...
# Processing 4zkY1SG-7xc.003...
# Processing PKyqjYem0dY.004...
# Processing 9UWCHrG5mys.001...
# Processing 9CPKW0sqR3E.005...
# Processing HPEemWelY1E.000...
# Processing AP0aklGHino.003...
# Processing FkzVX7SQ9wE.002...
# Processing kL-CeaXG9jM.002...
# Processing LuLUAwn0aWU.002...
# Processing obr7ktzX8w8.004...
# Processing P6g1mZ3f76U.002...
# Processing -Wqk9eex6bQ.002...
# Processing vhugKRUnd-c.004...
# Processing _7hGh6VU4IU.005...
# Processing jZhlaIUFMLc.000...
# Processing 5ghk5950BhU.005...
# Processing KnbEca4Ibwk.000...
# Processing 39BJkEXJpgc.003...
# Processing C2MEPH7x9m0.001...
# Processing cY3nHc5fDYE.003...
# Processing W0LRjSS9pVM.004...
# Processing 6WSr4IW6cNI.003...
# Processing J4GQm9j0JZ0.000...
# Processing Nv0-x4K9YFI.002...
# Processing _Q4wOgixh7E.000...
# Processing VtYPH6UsVnU.001...
# Processing 6NHEp_CF2jE.000...
# Processing p5v75vAZ7F0.003...
# Processing V9roK_mLM-w.000...
# Processing RrvG7JlKoXM.004...
# Processing DGCGeNlA-Ww.005...
# Processing lLObIVKYDUI.005...
# Processing UvX6ctu2ObM.002...
# Processing Pb7aNc6Kd40.005...
# Processing 3WoXkI06zGk.003...
# Processing djsoQkroHpo.003...
# Processing YocrYFLm4CM.002...
# Processing kY_4WyAXxrQ.004...
# Processing p6jjj6jn2fM.003...
# Processing Etw3iulV5Eg.001...
# Processing -R2SZu3SYgM.004...
# Processing Fi1ILrwQpSY.002...
# Processing 2PSGksTyrnI.001...
# Processing uf_sIIw4zxY.005...
# Processing u_qvbRpm88k.002...
# Processing KahSwziq8F0.003...
# Processing 9ND95tPlYt4.000...
# Processing oe1PZxExhzc.003...
# Processing JTmq4k4uQCY.000...
# Processing ce7t2PgzMGw.000...
# Processing oYiWW-Qc0rs.001...
# Processing nCWEEoJfjgE.004...
# Processing e2pnS_nT9rA.001...
# Processing tZiRqu8joX8.003...
# Processing ZoHY-rWJsyw.004...
# Processing Zi7QHI_5ipU.000...
# Processing mXaI17Dx7u0.003...
# Processing jFx6AEw6viQ.002...
# Processing qVrXROy4Ais.000...
# Processing ssxo35zmKWQ.003...
# Processing TUaOp5eIU2c.003...
# Processing sBHv1jYmZQE.004...
# Processing 9CPKW0sqR3E.001...
# Processing rIRBEkDhn6Q.005...
# Processing Fco1CMgOadI.002...
# Processing z54OqeICELg.004...
# Processing NpiglwrZzsA.004...
# Processing kDXYolv-8p8.003...
# Processing QNVsr2mGwGs.005...
# Processing 8-OKP1nf19E.000...
# Processing BmDClgdWlH4.000...
# Processing kL-CeaXG9jM.000...
# Processing QiPb8vlGDFo.004...
# Processing PxkMDzORBPE.005...
# Processing OugdInDyt9s.005...
# Processing cvg03XGFjCk.004...
# Processing 5f6s8cwA7WQ.001...
# Processing ADa9rkwF2uA.002...
# Processing _ZAqTHlu2ts.004...
# Processing RrvG7JlKoXM.002...
# Processing QTtTAFqT-no.004...
# Processing ZNRfeL8nPfw.001...
# Processing a5-PJqy9QmU.001...
# Processing 6N02tjYPLh8.000...
# Processing c3esnCQDoKc.004...
# Processing ivpw58MIRtQ.005...
# Processing OCMseWyLuBQ.001...
# Processing PtA7yAu9-VE.000...
# Processing 1ZqHFoxLz54.000...
# Processing 7nhJXn9PI0I.001...
# Processing ZRrduU1CXqU.001...
# Processing ZO5JoyVTat8.004...
# Processing _fJcW5234bY.004...
# Processing RYG6XhdmPY0.002...
# Processing VvVigAr4hZc.003...
# Processing NTxMChSejQE.001...
# Processing wzCdM6Fe_4A.001...
# Processing okl467xvgOw.001...
# Processing UANQntvIqVk.000...
# Processing ezMO8EHKAVw.004...
# Processing ZoHY-rWJsyw.000...
# Processing lKePJbjYiy0.000...
# Processing wYZJ2HXfvmQ.003...
# Processing n4NkVZ1_dfk.000...
# Processing II2KVV-uLNI.002...
# Processing 2x8GZaBY6TM.002...
# Processing KYvMsMLNGvY.005...
# Processing RthpiC1KtSg.004...
# Processing 2yUnXroXyeI.003...
# Processing TursJyaFzqY.003...
# Processing t0AupkXkkZw.001...
# Processing uE2U_Y7QrIw.000...
# Processing VmXZ2jMWuvk.001...
# Processing L-C1blPD_ec.004...
# Processing _zI6qgTJOSA.005...
# Processing VM409fZmJE0.000...
# Processing mxLRr3YqgMU.001...
# Processing 3JAFkk42zPs.004...
# Processing 5kaqMZ7SB9w.002...
# Processing v0jtovM6Ajg.003...
# Processing nfN9qJSVank.004...
# Processing ndLtwmvPpr8.000...
# Processing l3IoZ_QmOQo.004...
# Processing lsVwEApsljU.003...
# Processing 836kYlEs9GI.002...
# Processing djsoQkroHpo.005...
# Processing fEZrAGQoh_g.002...
# Processing It0-yCwOc5k.003...
# Processing gCQT7zfS7sI.002...
# Processing oCb9DK3M1DU.000...
# Processing OXkDmd3nA94.003...
# Processing FxVUG2R1y0Q.004...
# Processing si_gZCrLa4A.001...
# All features saved to audio_feature_extraction/train_4_af.csv

# %%
print("done")
# Out:
# done

# %% [markdown]
# ## DEEP AND HC FEATURE EXTRACTION

# %%
import os

def list_audio_files(base_dir, extension=".wav"):
    """
    List all audio files in the dataset directory.

    :param base_dir: Path to the dataset base directory
    :param extension: File extension to look for (default is ".wav")
    :return: List of file paths for all audio files
    """
    audio_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(extension):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Example usage
base_dir = "/kaggle/working/fi_audio_train_dataset/train-5"  # Replace with the path to your dataset
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 1040 audio files.

# %%
import os
import pandas as pd

output_dir = "audio_feature_extraction"

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Define output file and columns
output_file = "audio_feature_extraction/train_5_af.csv"
columns = ['Audio_ID', 'Segment_ID'] + [f'Deep_{i}' for i in range(512)] + [f'Hc_{i}' for i in range(25)]

# Initialize the CSV if it doesn't exist
if not os.path.exists(output_file):
    pd.DataFrame(columns=columns).to_csv(output_file, index=False)

# %%
from pydub import AudioSegment

def segment_audio(audio_path, segment_duration=2, skip_duration=3):
    audio = AudioSegment.from_file(audio_path)
    segments = []
    audio_duration = len(audio) / 1000  # in seconds
    for start in range(0, int(audio_duration - segment_duration), skip_duration):  # Segment based on audio length
        segment = audio[start * 1000:(start + segment_duration) * 1000]  # Segment duration in milliseconds
        if len(segment) < segment_duration * 1000:
            segment = segment + AudioSegment.silent(duration=(segment_duration * 1000 - len(segment)))  # Pad with silence
        segments.append(segment)
    return segments

# %%
import numpy as np
import librosa
from PIL import Image
import torch
import torchvision.transforms as transforms

# Load pretrained emotional VGG-16 model
vgg_model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', pretrained=True)
vgg_model.eval()

def extract_deep_features(segments):
    features = []
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    for segment in segments:
        # Compute log-Mel spectrogram
        samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
        mel_spec = librosa.feature.melspectrogram(y=samples, sr=16000, n_mels=128, fmax=8000, hop_length=512, win_length=2048)
        log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram to range 0-255 for image conversion
        log_mel_spec = np.clip(log_mel_spec, a_min=-80, a_max=0)  # Log scale
        log_mel_spec = (log_mel_spec + 80) * (255.0 / 80.0)  # Normalize to [0, 255]

        # Convert to image and resize
        image = Image.fromarray(log_mel_spec.astype(np.uint8)).convert("RGB")
        image = transform(image).unsqueeze(0)

        # Extract features using VGG-16
        with torch.no_grad():
            deep_feature = vgg_model(image).numpy()
        features.append(deep_feature)

    return features
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
pip install opensmile
# Out:
# Collecting opensmile
#   Downloading opensmile-2.5.0-py3-none-manylinux_2_17_x86_64.whl.metadata (15 kB)
# Collecting audobject>=0.6.1 (from opensmile)
#   Downloading audobject-0.7.11-py3-none-any.whl.metadata (2.6 kB)
# Collecting audinterface>=0.7.0 (from opensmile)
#   Downloading audinterface-1.2.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting audeer>=1.18.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audeer-2.2.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting audformat<2.0.0,>=1.0.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audformat-1.3.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting audiofile>=1.3.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audiofile-1.5.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting audmath>=1.4.1 (from audinterface>=0.7.0->opensmile)
#   Downloading audmath-1.4.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting audresample<2.0.0,>=1.1.0 (from audinterface>=0.7.0->opensmile)
#   Downloading audresample-1.3.3-py3-none-manylinux_2_17_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from audobject>=0.6.1->opensmile) (7.0.0)
# Collecting oyaml (from audobject>=0.6.1->opensmile)
#   Downloading oyaml-1.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from audobject>=0.6.1->opensmile) (21.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from audeer>=1.18.0->audinterface>=0.7.0->opensmile) (4.66.4)
# Collecting iso639-lang (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso639_lang-2.5.1-py3-none-any.whl.metadata (9.2 kB)
# Collecting iso3166 (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile)
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.2.3)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (17.0.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /opt/conda/lib/python3.10/site-packages (from audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (6.0.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.26.4)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=4.8.0->audobject>=0.6.1->opensmile) (3.19.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->audobject>=0.6.1->opensmile) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (2024.1)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.3.0->audinterface>=0.7.0->opensmile) (2.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->audformat<2.0.0,>=1.0.1->audinterface>=0.7.0->opensmile) (1.16.0)
# Downloading opensmile-2.5.0-py3-none-manylinux_2_17_x86_64.whl (996 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 996.2/996.2 kB 28.0 MB/s eta 0:00:0000:01
# Downloading audinterface-1.2.2-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 4.9 MB/s eta 0:00:00
# Downloading audobject-0.7.11-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
# Downloading audeer-2.2.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.5 MB/s eta 0:00:00
# Downloading audformat-1.3.1-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 10.3 MB/s eta 0:00:00
# Downloading audiofile-1.5.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.1 MB/s eta 0:00:00
# Downloading audmath-1.4.1-py3-none-any.whl (23 kB)
# Downloading audresample-1.3.3-py3-none-manylinux_2_17_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.4/138.4 kB 10.1 MB/s eta 0:00:00
# Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Downloading iso639_lang-2.5.1-py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 22.5 MB/s eta 0:00:00
# Installing collected packages: oyaml, iso639-lang, iso3166, audresample, audmath, audeer, audobject, audiofile, audformat, audinterface, opensmile
# Successfully installed audeer-2.2.0 audformat-1.3.1 audinterface-1.2.2 audiofile-1.5.0 audmath-1.4.1 audobject-0.7.11 audresample-1.3.3 iso3166-2.1.1 iso639-lang-2.5.1 opensmile-2.5.0 oyaml-1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import opensmile
from opensmile import Smile, FeatureSet, FeatureLevel

smile = Smile(
    feature_set=FeatureSet.eGeMAPSv02,
    feature_level=FeatureLevel.Functionals
)

def extract_egemaps(segment):
    """
    Extract eGeMAPS features using openSMILE.

    :param segment: Audio segment
    :return: Hand-crafted features as a numpy array
    """
    samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
    features = smile.process_signal(samples, sampling_rate=16000).to_numpy()
    return features

# %%
def save_features(audio_id, segment_id, deep_feat, hc_feat):
    """
    Save the extracted features to the CSV file.

    :param audio_id: ID of the audio file
    :param segment_id: ID of the audio segment
    :param deep_feat: Deep features for the segment
    :param hc_feat: Hand-crafted features for the segment
    """
    # Aggregate features (e.g., mean)
    combined_features = {
        'Audio_ID': audio_id,
        'Segment_ID': segment_id,
    }
    combined_features.update({f'Deep_{i}': deep_feat.mean(axis=0)[i] for i in range(512)})
    combined_features.update({f'Hc_{i}': hc_feat.mean(axis=0)[i] for i in range(25)})

    # Append to CSV
    feature_row = pd.DataFrame([combined_features])
    feature_row.to_csv(output_file, mode='a', header=False, index=False)

# %%
def process_audio_files(audio_files):
    for audio_path in audio_files:
        audio_id = os.path.splitext(os.path.basename(audio_path))[0]
        print(f"Processing {audio_id}...")

        # Segment the audio
        segments = segment_audio(audio_path)

        for segment_id, segment in enumerate(segments):
            # Extract features
            deep_feat = extract_deep_features([segment])[0]
            hc_feat = extract_egemaps(segment)

            # Save features to CSV
            save_features(audio_id, segment_id, deep_feat, hc_feat)

    print(f"All features saved to {output_file}")

# %%
# Step 1: List all audio files in the dataset directory
# base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with your path
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")

# Step 2: Process all audio files
process_audio_files(audio_files)  # This function is already defined in the previous pipeline
# Out:
# Found 1040 audio files.
# Processing NvwD448H-40.001...
# Processing f39E4ct09Cc.000...
# Processing sBHv1jYmZQE.003...
# Processing xA3GCTL5o-k.000...
# Processing GTmHSF6vNWc.002...
# Processing c2LeNguVNrI.002...
# Processing 4kIHxR6s1L4.001...
# Processing XPV4pavXh94.001...
# Processing RvoxbgEP49Q.003...
# Processing MuYYY3XaJ7Q.005...
# Processing nQxTTYWy7pA.001...
# Processing MkVsl0hdphE.000...
# Processing dmOKZLeFKCM.002...
# Processing WUNXs4r_xCU.002...
# Processing 8py6SksNsZQ.002...
# Processing xmD4FKMq2rk.000...
# Processing sPMNhG1Sehc.005...
# Processing HWuh0biZQ_c.001...
# Processing RsYSOFRFszk.001...
# Processing b39BQbVhOAg.004...
# Processing s1DOqsQoN5s.002...
# Processing ua5c716lu5s.005...
# Processing cyma9Q6QF6M.001...
# Processing 2TMl5EMrdVI.005...
# Processing laPGbkC87us.004...
# Processing wr4dP9MuHME.004...
# Processing o7J2fWIJndQ.005...
# Processing HhC2cGFFZeY.001...
# Processing ztyBhnjtrz0.003...
# Processing jrhvXPaXo-0.000...
# Processing 5Wmlo8Z5yVA.003...
# Processing 9a-3LrB7cDI.005...
# Processing KB09jENVJ_0.002...
# Processing LWylAwr9kJI.001...
# Processing I5x9T9ftW18.005...
# Processing kp3c66Igyr8.005...
# Processing ly_0m16694Q.000...
# Processing Q0C0OU-j4DA.004...
# Processing sf8TXpaKnt4.001...
# Processing BjQ95T-Dw1U.004...
# Processing AZ2HyBOmliQ.005...
# Processing Y8gv_ZK3w4A.000...
# Processing twO6ceVTuII.002...
# Processing 8Z6PrQdqffA.005...
# Processing JlMPF03b8SM.001...
# Processing voSLxKtKr0Q.005...
# Processing UKHSKkb0V1o.004...
# Processing xbAb00tGeBQ.000...
# Processing a84s1DYag-I.004...
# Processing 13kjwEtSyXc.000...
# Processing siEnTktB4lQ.004...
# Processing IwfA-squ7Oo.004...
# Processing 7gyJdWaLpmE.003...
# Processing fSDA4eEyGHk.000...
# Processing OtGJDbI9qkM.000...
# Processing TD2jIXMD-SM.002...
# Processing gipWTZy9mjI.000...
# Processing OwI3Q-qUqDw.005...
# Processing AJIphVRpYrg.003...
# Processing nLuAoNAOGcQ.000...
# Processing QiPb8vlGDFo.002...
# Processing 3Vr5-zedeWk.000...
# All features saved to audio_feature_extraction/train_5_af.csv

# %%
print("done")
# Out:
# done

# %% [markdown]
# ## DEEP AND HC FEATURE EXTRACTION

# %%
import os

def list_audio_files(base_dir, extension=".wav"):
    """
    List all audio files in the dataset directory.

    :param base_dir: Path to the dataset base directory
    :param extension: File extension to look for (default is ".wav")
    :return: List of file paths for all audio files
    """
    audio_files = []
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(extension):
                audio_files.append(os.path.join(root, file))
    return audio_files

# Example usage
base_dir = "/kaggle/working/fi_audio_train_dataset/train-6"  # Replace with the path to your dataset
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")
# Out:
# Found 1120 audio files.

# %%
import os
import pandas as pd

output_dir = "audio_feature_extraction"

# Create output directory if not exists
os.makedirs(output_dir, exist_ok=True)

# Define output file and columns
output_file = "audio_feature_extraction/train_6_af.csv"
columns = ['Audio_ID', 'Segment_ID'] + [f'Deep_{i}' for i in range(512)] + [f'Hc_{i}' for i in range(25)]

# Initialize the CSV if it doesn't exist
if not os.path.exists(output_file):
    pd.DataFrame(columns=columns).to_csv(output_file, index=False)

# %%
from pydub import AudioSegment

def segment_audio(audio_path, segment_duration=2, skip_duration=3):
    audio = AudioSegment.from_file(audio_path)
    segments = []
    audio_duration = len(audio) / 1000  # in seconds
    for start in range(0, int(audio_duration - segment_duration), skip_duration):  # Segment based on audio length
        segment = audio[start * 1000:(start + segment_duration) * 1000]  # Segment duration in milliseconds
        if len(segment) < segment_duration * 1000:
            segment = segment + AudioSegment.silent(duration=(segment_duration * 1000 - len(segment)))  # Pad with silence
        segments.append(segment)
    return segments

# %%
import numpy as np
import librosa
from PIL import Image
import torch
import torchvision.transforms as transforms

# Load pretrained emotional VGG-16 model
vgg_model = torch.hub.load('pytorch/vision:v0.10.0', 'vgg16', pretrained=True)
vgg_model.eval()

def extract_deep_features(segments):
    features = []
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    for segment in segments:
        # Compute log-Mel spectrogram
        samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
        mel_spec = librosa.feature.melspectrogram(y=samples, sr=16000, n_mels=128, fmax=8000, hop_length=512, win_length=2048)
        log_mel_spec = librosa.power_to_db(mel_spec, ref=np.max)

        # Normalize the spectrogram to range 0-255 for image conversion
        log_mel_spec = np.clip(log_mel_spec, a_min=-80, a_max=0)  # Log scale
        log_mel_spec = (log_mel_spec + 80) * (255.0 / 80.0)  # Normalize to [0, 255]

        # Convert to image and resize
        image = Image.fromarray(log_mel_spec.astype(np.uint8)).convert("RGB")
        image = transform(image).unsqueeze(0)

        # Extract features using VGG-16
        with torch.no_grad():
            deep_feature = vgg_model(image).numpy()
        features.append(deep_feature)

    return features
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# pip install opensmile

# %%
import opensmile
from opensmile import Smile, FeatureSet, FeatureLevel

smile = Smile(
    feature_set=FeatureSet.eGeMAPSv02,
    feature_level=FeatureLevel.Functionals
)

def extract_egemaps(segment):
    """
    Extract eGeMAPS features using openSMILE.

    :param segment: Audio segment
    :return: Hand-crafted features as a numpy array
    """
    samples = np.array(segment.get_array_of_samples(), dtype=np.float32)
    features = smile.process_signal(samples, sampling_rate=16000).to_numpy()
    return features

# %%
def save_features(audio_id, segment_id, deep_feat, hc_feat):
    """
    Save the extracted features to the CSV file.

    :param audio_id: ID of the audio file
    :param segment_id: ID of the audio segment
    :param deep_feat: Deep features for the segment
    :param hc_feat: Hand-crafted features for the segment
    """
    # Aggregate features (e.g., mean)
    combined_features = {
        'Audio_ID': audio_id,
        'Segment_ID': segment_id,
    }
    combined_features.update({f'Deep_{i}': deep_feat.mean(axis=0)[i] for i in range(512)})
    combined_features.update({f'Hc_{i}': hc_feat.mean(axis=0)[i] for i in range(25)})

    # Append to CSV
    feature_row = pd.DataFrame([combined_features])
    feature_row.to_csv(output_file, mode='a', header=False, index=False)

# %%
def process_audio_files(audio_files):
    for audio_path in audio_files:
        audio_id = os.path.splitext(os.path.basename(audio_path))[0]
        print(f"Processing {audio_id}...")

        # Segment the audio
        segments = segment_audio(audio_path)

        for segment_id, segment in enumerate(segments):
            # Extract features
            deep_feat = extract_deep_features([segment])[0]
            hc_feat = extract_egemaps(segment)

            # Save features to CSV
            save_features(audio_id, segment_id, deep_feat, hc_feat)

    print(f"All features saved to {output_file}")

# %%
# Step 1: List all audio files in the dataset directory
# base_dir = "/kaggle/working/fi_audio_train_dataset/train-2"  # Replace with your path
audio_files = list_audio_files(base_dir)
print(f"Found {len(audio_files)} audio files.")

# Step 2: Process all audio files
process_audio_files(audio_files)  # This function is already defined in the previous pipeline
# Out:
# Found 1120 audio files.
# Processing rGNeR3p1jKU.001...
# Processing ezMO8EHKAVw.000...
# Processing 4yogPbHFQ9o.002...
# Processing 38fE5B4ghw0.005...
# Processing JciLbidX1Q8.003...
# Processing o-fNF5QVMNo.004...
# Processing jz9kgvYbBYA.005...
# Processing Rwsss8y1bf0.002...
# Processing NpiglwrZzsA.001...
# Processing OmXuhT4yJpo.005...
# Processing PReOtefm17s.002...
# Processing 13kjwEtSyXc.002...
# Processing pHCPbKprJGY.003...
# Processing kp3c66Igyr8.004...
# Processing BjQ95T-Dw1U.005...
# Processing gAWA-fcIa_M.001...
# Processing vo-Y5kgSBa8.005...
# Processing Y-YdRocu0os.001...
# Processing Etfh8X-ECtY.002...
# Processing DVh_7dO2cWY.004...
# Processing WZnLayQeIZ0.005...
# Processing 3gKpBq-1yG4.004...
# Processing 300gK3CnzW0.000...
# Processing IFF47jVKMj8.004...
# Processing HCkDd0UnUgo.004...
# Processing oe1PZxExhzc.001...
# Processing cx8IycWgMVs.003...
# Processing NXG4n1pr4Ok.002...
# Processing K3-YXXLR0Ho.000...
# Processing MvWDky9ZaWU.003...
# Processing YNlhBpVk1tw.002...
# Processing JxxF9y61ujA.004...
# Processing cpzY1b6wJqs.002...
# Processing -55DRRMTppE.000...
# Processing gFEntQ_UKvk.003...
# Processing zH9pTx5_ZwY.004...
# Processing uHrP02iwW1o.000...
# Processing VhHnmeRABJw.005...
# Processing o_kTWEEjtyw.003...
# Processing FvjIziLzffo.004...
# Processing LuLUAwn0aWU.000...
# Processing 8z-WF2UNRb8.002...
# Processing mhvkJjOAjYI.004...
# Processing dLaqub4BEsA.003...
# Processing _IS6GFmQYj4.004...
# Processing NBacfF-K2eQ.000...
# Processing 7ZnijRlK5-E.002...
# Processing P0ZzjnS8E24.000...
# Processing h_GDQ9_H1es.002...
# Processing d4cPiUXpGbc.002...
# Processing W8NkAXNboT0.000...
# Processing Y6iogSmj6FQ.003...
# Processing IHJn3UHXCMs.004...
# Processing oVSMxtPpQ0M.005...
# Processing vOxgWKGNEYc.000...
# Processing dmycfNpiWCE.002...
# Processing AWZLchLstio.003...
# Processing OZlpENU9h28.002...
# Processing RYG6XhdmPY0.004...
# Processing Cng72emlXAM.004...
# Processing Shf0JB_MutI.001...
# Processing Cvuu76B-bxA.003...
# Processing N7oR6_oMBFk.004...
# All features saved to audio_feature_extraction/train_6_af.csv

# %%
print("done")
# Out:
# done

# %%
import os
import zipfile

def compress_folder_to_zip(folder_path, output_zip_path):
    # Check if the folder exists
    if not os.path.isdir(folder_path):
        raise ValueError(f"Folder path '{folder_path}' does not exist.")
    
    # Ensure the output file has the `.zip` extension
    if not output_zip_path.endswith(".zip"):
        output_zip_path += ".zip"

    # Create a ZIP file
    with zipfile.ZipFile(output_zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                # Add file to ZIP with a relative path
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

    print(f"Folder successfully compressed into: {output_zip_path}")

# Example usage
folder_path = "/kaggle/working/audio_feature_extraction"  # Replace with your folder path on Kaggle
output_zip_path = "/kaggle/working/audio_feature_extraction.zip"  # Output file will be saved in the working directory

compress_folder_to_zip(folder_path, output_zip_path)
# Out:
# Folder successfully compressed into: /kaggle/working/audio_feature_extraction.zip
